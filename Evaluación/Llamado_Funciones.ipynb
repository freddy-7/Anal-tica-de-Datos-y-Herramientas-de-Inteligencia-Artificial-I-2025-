# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import Freddy as fd

# %%
#Se realiza el llamado a la función "cargar_dataset" para leer el archivo
df=fd.cargar_dataset('Albany.csv')

# %%
pd.options.display.max_rows= None

# %%
#Se obtiene la información general del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            429 non-null    int64
#  1   listing_url                                   429 non-null    object
#  2   scrape_id                                     429 non-null    int64
#  3   last_scraped                                  429 non-null    object
#  4   source                                        429 non-null    object
#  5   name                                          429 non-null    object
#  6   description                                   422 non-null    object
#  7   neighborhood_overview                         213 non-null    object
#  8   picture_url                                   429 non-null    object
#  9   host_id                                       429 non-null    int64
#  10  host_url                                      429 non-null    object
#  11  host_name                                     429 non-null    object
#  12  host_since                                    429 non-null    object
#  13  host_location                                 343 non-null    object
#  14  host_about                                    234 non-null    object
#  15  host_response_time                            408 non-null    object
#  16  host_response_rate                            408 non-null    object
#  17  host_acceptance_rate                          420 non-null    object
#  18  host_is_superhost                             414 non-null    object
#  19  host_thumbnail_url                            429 non-null    object
#  20  host_picture_url                              429 non-null    object
#  21  host_neighbourhood                            363 non-null    object
#  22  host_listings_count                           429 non-null    int64
#  23  host_total_listings_count                     429 non-null    int64
#  24  host_verifications                            429 non-null    object
#  25  host_has_profile_pic                          429 non-null    object
#  26  host_identity_verified                        429 non-null    object
#  27  neighbourhood                                 213 non-null    object
#  28  neighbourhood_cleansed                        429 non-null    object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      429 non-null    float64
#  31  longitude                                     429 non-null    float64
#  32  property_type                                 429 non-null    object
#  33  room_type                                     429 non-null    object
#  34  accommodates                                  429 non-null    int64
#  35  bathrooms                                     395 non-null    float64
#  36  bathrooms_text                                429 non-null    object
#  37  bedrooms                                      424 non-null    float64
#  38  beds                                          394 non-null    float64
#  39  amenities                                     429 non-null    object
#  40  price                                         395 non-null    object
#  41  minimum_nights                                429 non-null    int64
#  42  maximum_nights                                429 non-null    int64
#  43  minimum_minimum_nights                        429 non-null    int64
#  44  maximum_minimum_nights                        429 non-null    int64
#  45  minimum_maximum_nights                        429 non-null    int64
#  46  maximum_maximum_nights                        429 non-null    int64
#  47  minimum_nights_avg_ntm                        429 non-null    float64
#  48  maximum_nights_avg_ntm                        429 non-null    float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              424 non-null    object
#  51  availability_30                               429 non-null    int64
#  52  availability_60                               429 non-null    int64
#  53  availability_90                               429 non-null    int64
#  54  availability_365                              429 non-null    int64
#  55  calendar_last_scraped                         429 non-null    object
#  56  number_of_reviews                             429 non-null    int64
#  57  number_of_reviews_ltm                         429 non-null    int64
#  58  number_of_reviews_l30d                        429 non-null    int64
#  59  first_review                                  374 non-null    object
#  60  last_review                                   374 non-null    object
#  61  review_scores_rating                          374 non-null    float64
#  62  review_scores_accuracy                        374 non-null    float64
#  63  review_scores_cleanliness                     374 non-null    float64
#  64  review_scores_checkin                         374 non-null    float64
#  65  review_scores_communication                   374 non-null    float64
#  66  review_scores_location                        374 non-null    float64
#  67  review_scores_value                           374 non-null    float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              429 non-null    object
#  70  calculated_host_listings_count                429 non-null    int64
#  71  calculated_host_listings_count_entire_homes   429 non-null    int64
#  72  calculated_host_listings_count_private_rooms  429 non-null    int64
#  73  calculated_host_listings_count_shared_rooms   429 non-null    int64
#  74  reviews_per_month                             374 non-null    float64
# dtypes: float64(18), int64(23), object(34)
# memory usage: 251.5+ KB

# %%
#Se realiza el llamado a la función "cuenta_nulos" para identificar nulos
nulos=fd.cuenta_nulos(df)
nulos
# Out:
# ('Valores nulos por columna',
#  id                                                0
#  listing_url                                       0
#  scrape_id                                         0
#  last_scraped                                      0
#  source                                            0
#  name                                              0
#  description                                       7
#  neighborhood_overview                           216
#  picture_url                                       0
#  host_id                                           0
#  host_url                                          0
#  host_name                                         0
#  host_since                                        0
#  host_location                                    86
#  host_about                                      195
#  host_response_time                               21
#  host_response_rate                               21
#  host_acceptance_rate                              9
#  host_is_superhost                                15
#  host_thumbnail_url                                0
#  host_picture_url                                  0
#  host_neighbourhood                               66
#  host_listings_count                               0
#  host_total_listings_count                         0
#  host_verifications                                0
#  host_has_profile_pic                              0
#  host_identity_verified                            0
#  neighbourhood                                   216
#  neighbourhood_cleansed                            0
#  neighbourhood_group_cleansed                    429
#  latitude                                          0
#  longitude                                         0
#  property_type                                     0
#  room_type                                         0
#  accommodates                                      0
#  bathrooms                                        34
#  bathrooms_text                                    0
#  bedrooms                                          5
#  beds                                             35
#  amenities                                         0
#  price                                            34
#  minimum_nights                                    0
#  maximum_nights                                    0
#  minimum_minimum_nights                            0
#  maximum_minimum_nights                            0
#  minimum_maximum_nights                            0
#  maximum_maximum_nights                            0
#  minimum_nights_avg_ntm                            0
#  maximum_nights_avg_ntm                            0
#  calendar_updated                                429
#  has_availability                                  5
#  availability_30                                   0
#  availability_60                                   0
#  availability_90                                   0
#  availability_365                                  0
#  calendar_last_scraped                             0
#  number_of_reviews                                 0
#  number_of_reviews_ltm                             0
#  number_of_reviews_l30d                            0
#  first_review                                     55
#  last_review                                      55
#  review_scores_rating                             55
#  review_scores_accuracy                           55
#  review_scores_cleanliness                        55
#  review_scores_checkin                            55
#  review_scores_communication                      55
#  review_scores_location                           55
#  review_scores_value                              55
#  license                                         429
#  instant_bookable                                  0
#  calculated_host_listings_count                    0
#  calculated_host_listings_count_entire_homes       0
#  calculated_host_listings_count_private_rooms      0
#  calculated_host_listings_count_shared_rooms       0
#  reviews_per_month                                55
#  dtype: int64,
#  'Valores nulos por dataframe',
#  np.int64(2802))

# %%
#Se realiza el llamado a la función "limpieza_nulos" para sustituir
#los valores nulos por los métodos establecidos
df=fd.limpieza_nulos(df)

# %%
#Se realiza el llamado a la función "cuenta_nulos" para identificar nulos
nulos=fd.cuenta_nulos(df)
nulos
# Out:
# ('Valores nulos por columna',
#  host_id                                           0
#  host_total_listings_count                         0
#  neighbourhood_group_cleansed                      0
#  longitude                                         0
#  bathrooms                                         0
#  bedrooms                                          0
#  minimum_nights                                    0
#  minimum_minimum_nights                            0
#  minimum_maximum_nights                            0
#  minimum_nights_avg_ntm                            0
#  calendar_updated                                  0
#  availability_30                                   0
#  availability_90                                   0
#  number_of_reviews_ltm                             0
#  review_scores_rating                              0
#  review_scores_cleanliness                         0
#  review_scores_communication                       0
#  review_scores_value                               0
#  calculated_host_listings_count_entire_homes       0
#  calculated_host_listings_count_shared_rooms       0
#  id                                                0
#  scrape_id                                         0
#  host_listings_count                               0
#  latitude                                          0
#  accommodates                                      0
#  beds                                              0
#  maximum_nights                                    0
#  maximum_minimum_nights                            0
#  maximum_maximum_nights                            0
#  maximum_nights_avg_ntm                            0
#  availability_60                                   0
#  availability_365                                  0
#  number_of_reviews                                 0
#  number_of_reviews_l30d                            0
#  review_scores_accuracy                            0
#  review_scores_checkin                             0
#  review_scores_location                            0
#  license                                         429
#  calculated_host_listings_count                    0
#  calculated_host_listings_count_private_rooms      0
#  reviews_per_month                                 0
#  listing_url                                       0
#  last_scraped                                      0
#  name                                              0
#  neighborhood_overview                             0
#  host_name                                         0
#  host_location                                     0
#  host_response_time                                0
#  host_acceptance_rate                              0
#  host_thumbnail_url                                0
#  host_neighbourhood                                0
#  host_has_profile_pic                              0
#  neighbourhood                                     0
#  room_type                                         0
#  amenities                                         0
#  calendar_last_scraped                             0
#  first_review                                      0
#  instant_bookable                                  0
#  source                                            0
#  description                                       0
#  picture_url                                       0
#  host_url                                          0
#  host_since                                        0
#  host_about                                        0
#  host_response_rate                                0
#  host_is_superhost                                 0
#  host_picture_url                                  0
#  host_verifications                                0
#  host_identity_verified                            0
#  neighbourhood_cleansed                            0
#  property_type                                     0
#  bathrooms_text                                    0
#  price                                             0
#  has_availability                                  0
#  last_review                                       0
#  dtype: int64,
#  'Valores nulos por dataframe',
#  np.int64(429))

# %%
Datos_limpios=fd.limpieza_atipicos(df)

# %%
#Se realiza el llamado a la función "cuenta_nulos" para identificar nulos
nulos=fd.cuenta_nulos(Datos_limpios)
nulos
# Out:
# ('Valores nulos por columna',
#  listing_url                                       0
#  last_scraped                                      0
#  name                                              0
#  neighborhood_overview                             0
#  host_name                                         0
#  host_location                                     0
#  host_response_time                                0
#  host_acceptance_rate                              0
#  host_thumbnail_url                                0
#  host_neighbourhood                                0
#  host_has_profile_pic                              0
#  neighbourhood                                     0
#  room_type                                         0
#  amenities                                         0
#  calendar_last_scraped                             0
#  first_review                                      0
#  instant_bookable                                  0
#  source                                            0
#  description                                       0
#  picture_url                                       0
#  host_url                                          0
#  host_since                                        0
#  host_about                                        0
#  host_response_rate                                0
#  host_is_superhost                                 0
#  host_picture_url                                  0
#  host_verifications                                0
#  host_identity_verified                            0
#  neighbourhood_cleansed                            0
#  property_type                                     0
#  bathrooms_text                                    0
#  price                                             0
#  has_availability                                  0
#  last_review                                       0
#  host_id                                           0
#  host_total_listings_count                         0
#  neighbourhood_group_cleansed                      0
#  longitude                                         0
#  bathrooms                                         0
#  bedrooms                                          0
#  minimum_nights                                    0
#  minimum_minimum_nights                            0
#  minimum_maximum_nights                            0
#  minimum_nights_avg_ntm                            0
#  calendar_updated                                  0
#  availability_30                                   0
#  availability_90                                   0
#  number_of_reviews_ltm                             0
#  review_scores_rating                              0
#  review_scores_cleanliness                         0
#  review_scores_communication                       0
#  review_scores_value                               0
#  calculated_host_listings_count_entire_homes       0
#  calculated_host_listings_count_shared_rooms       0
#  id                                                0
#  scrape_id                                         0
#  host_listings_count                               0
#  latitude                                          0
#  accommodates                                      0
#  beds                                              0
#  maximum_nights                                    0
#  maximum_minimum_nights                            0
#  maximum_maximum_nights                            0
#  maximum_nights_avg_ntm                            0
#  availability_60                                   0
#  availability_365                                  0
#  number_of_reviews                                 0
#  number_of_reviews_l30d                            0
#  review_scores_accuracy                            0
#  review_scores_checkin                             0
#  review_scores_location                            0
#  license                                         429
#  calculated_host_listings_count                    0
#  calculated_host_listings_count_private_rooms      0
#  reviews_per_month                                 0
#  dtype: int64,
#  'Valores nulos por dataframe',
#  np.int64(429))

# %%
Datos_limpios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   listing_url                                   429 non-null    object
#  1   last_scraped                                  429 non-null    object
#  2   name                                          429 non-null    object
#  3   neighborhood_overview                         429 non-null    object
#  4   host_name                                     429 non-null    object
#  5   host_location                                 429 non-null    object
#  6   host_response_time                            429 non-null    object
#  7   host_acceptance_rate                          429 non-null    object
#  8   host_thumbnail_url                            429 non-null    object
#  9   host_neighbourhood                            429 non-null    object
#  10  host_has_profile_pic                          429 non-null    object
#  11  neighbourhood                                 429 non-null    object
#  12  room_type                                     429 non-null    object
#  13  amenities                                     429 non-null    object
#  14  calendar_last_scraped                         429 non-null    object
#  15  first_review                                  429 non-null    object
#  16  instant_bookable                              429 non-null    object
#  17  source                                        429 non-null    object
#  18  description                                   429 non-null    object
#  19  picture_url                                   429 non-null    object
#  20  host_url                                      429 non-null    object
#  21  host_since                                    429 non-null    object
#  22  host_about                                    429 non-null    object
#  23  host_response_rate                            429 non-null    object
#  24  host_is_superhost                             429 non-null    object
#  25  host_picture_url                              429 non-null    object
#  26  host_verifications                            429 non-null    object
#  27  host_identity_verified                        429 non-null    object
#  28  neighbourhood_cleansed                        429 non-null    object
#  29  property_type                                 429 non-null    object
#  30  bathrooms_text                                429 non-null    object
#  31  price                                         429 non-null    object
#  32  has_availability                              429 non-null    object
#  33  last_review                                   429 non-null    object
#  34  host_id                                       429 non-null    int64
#  35  host_total_listings_count                     429 non-null    float64
#  36  neighbourhood_group_cleansed                  429 non-null    float64
#  37  longitude                                     429 non-null    float64
#  38  bathrooms                                     429 non-null    float64
#  39  bedrooms                                      429 non-null    float64
#  40  minimum_nights                                429 non-null    float64
#  41  minimum_minimum_nights                        429 non-null    float64
#  42  minimum_maximum_nights                        429 non-null    int64
#  43  minimum_nights_avg_ntm                        429 non-null    float64
#  44  calendar_updated                              429 non-null    float64
#  45  availability_30                               429 non-null    int64
#  46  availability_90                               429 non-null    int64
#  47  number_of_reviews_ltm                         429 non-null    float64
#  48  review_scores_rating                          429 non-null    float64
#  49  review_scores_cleanliness                     429 non-null    float64
#  50  review_scores_communication                   429 non-null    float64
#  51  review_scores_value                           429 non-null    float64
#  52  calculated_host_listings_count_entire_homes   429 non-null    float64
#  53  calculated_host_listings_count_shared_rooms   429 non-null    float64
#  54  id                                            429 non-null    int64
#  55  scrape_id                                     429 non-null    int64
#  56  host_listings_count                           429 non-null    float64
#  57  latitude                                      429 non-null    float64
#  58  accommodates                                  429 non-null    float64
#  59  beds                                          429 non-null    float64
#  60  maximum_nights                                429 non-null    int64
#  61  maximum_minimum_nights                        429 non-null    float64
#  62  maximum_maximum_nights                        429 non-null    int64
#  63  maximum_nights_avg_ntm                        429 non-null    float64
#  64  availability_60                               429 non-null    int64
#  65  availability_365                              429 non-null    int64
#  66  number_of_reviews                             429 non-null    float64
#  67  number_of_reviews_l30d                        429 non-null    float64
#  68  review_scores_accuracy                        429 non-null    float64
#  69  review_scores_checkin                         429 non-null    float64
#  70  review_scores_location                        429 non-null    float64
#  71  license                                       0 non-null      float64
#  72  calculated_host_listings_count                429 non-null    float64
#  73  calculated_host_listings_count_private_rooms  429 non-null    float64
#  74  reviews_per_month                             429 non-null    float64
# dtypes: float64(31), int64(10), object(34)
# memory usage: 251.5+ KB

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("Datos_limpios.csv")
